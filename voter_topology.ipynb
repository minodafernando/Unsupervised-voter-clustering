# %%
import pandas as pd

df_demo = pd.read_excel(
    "2021 Pew Research Typology Detailed Tables.xlsx",
    sheet_name="Demographics and lifestyle",
    skiprows=range(0,10)
)

df_demo.head(10)
# Out:
#                                         Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0                                           AGECAT         NaN         NaN
# 1                                              Age         NaN         NaN
# 2                                            18-29        19.0         8.0
# 3                                            30-49        34.0        24.0
# 4                                            50-64        25.0        34.0
# 5                                              65+        21.0        33.0
# 6                                          Refused         1.0         1.0
# 7  Survey of U.S. adults conducted July 8-18, 2021         NaN         NaN
# 8                                              NaN         NaN         NaN
# 9                                       RACETHNMOD         NaN         NaN
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  \
# ...
